# %%
from manim import *

# %%
# %%manim -ql -v WARNING LinearTransformationSceneExample2
#
# class LinearTransformationSceneExample2(LinearTransformationScene):
#     def construct(self):
#         matrix = [[2, 0], [0, 1]]
#         self.add_unit_square()
#         self.apply_matrix(matrix)
#         self.wait()
# Out:
# <video src="media\jupyter\LinearTransformationSceneExample2@2023-02-26@10-58-54.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -v WARNING -ql --format=gif HelloManim
#
# class HelloManim(Scene):
#     def construct(self):
#         self.camera.background_color = "#ece6e2"
#         banner_large = ManimBanner(dark_theme=False).scale(0.7)
#         self.play(banner_large.create())
#         self.play(banner_large.expand())
