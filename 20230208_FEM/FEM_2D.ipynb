# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym
from scipy.integrate import quad_vec as scipy_integrate_quad_vec

from plotting import *

# %% [markdown]
# # Finite Element Method (FEM)
# Weak formulation: $\underline \underline K \, \underline u = \underline f$

# %% [markdown]
# ## Example (2D)

# %% [markdown]
# Mesh

# %%
node_list = np.array([
    [0,0],
    [1,0],
    [2,0],
    [0,1],
    [1,1],
    [2,1],
    [0,2],
    [1,2],
    [2,2],
])
element_list = [
    [3,4,1,0],
    [4,5,2,1],
    [6,7,4,3],
    [7,8,5,4],
]

n_nodes = len(node_list)
n_elements = len(element_list)

plot_2D_mesh(node_list, element_list)
